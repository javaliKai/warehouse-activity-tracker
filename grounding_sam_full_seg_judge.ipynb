# %% [markdown]
# # Clone Repo

# %%
# Clone cleaned up repo
# !git clone https://github.com/javaliKai/warehouse-activity-tracker.git
# Out:
# Cloning into 'warehouse-activity-tracker'...
# remote: Enumerating objects: 1530, done.
# remote: Counting objects: 100% (42/42), done.
# remote: Compressing objects: 100% (33/33), done.
# remote: Total 1530 (delta 20), reused 28 (delta 9), pack-reused 1488 (from 1)
# Receiving objects: 100% (1530/1530), 158.01 MiB | 43.42 MiB/s, done.
# Resolving deltas: 100% (487/487), done.

# %% [markdown]
# # Install Deps

# %%
# verify pytorch installation
import torch
print("Torch:", torch.__version__)
print("CUDA available:", torch.cuda.is_available())
print("CUDA version:", torch.version.cuda)
# Out:
# Torch: 2.10.0+cu128
# CUDA available: True
# CUDA version: 12.8

# %%
# set cuda home
import os
os.environ["CUDA_HOME"] = "/usr/local/cuda"  # this is the default google colab location of cuda
print(os.environ["CUDA_HOME"])
# Out:
# /usr/local/cuda

# %%
# install SAM2
# !cd warehouse-activity-tracker && pip install -e .
# Out:
# Obtaining file:///content/warehouse-activity-tracker
#   Installing build dependencies ... done
#   Checking if build backend supports build_editable ... done
#   Getting requirements to build editable ... done
#   Preparing editable metadata (pyproject.toml) ... done
# Requirement already satisfied: torch>=2.3.1 in /usr/local/lib/python3.12/dist-packages (from SAM-2==1.0) (2.10.0+cu128)
# Requirement already satisfied: torchvision>=0.18.1 in /usr/local/lib/python3.12/dist-packages (from SAM-2==1.0) (0.25.0+cu128)
# Requirement already satisfied: numpy>=1.24.4 in /usr/local/lib/python3.12/dist-packages (from SAM-2==1.0) (2.0.2)
# Requirement already satisfied: tqdm>=4.66.1 in /usr/local/lib/python3.12/dist-packages (from SAM-2==1.0) (4.67.3)
# Collecting hydra-core>=1.3.2 (from SAM-2==1.0)
#   Downloading hydra_core-1.3.2-py3-none-any.whl.metadata (5.5 kB)
# Collecting iopath>=0.1.10 (from SAM-2==1.0)
#   Downloading iopath-0.1.10.tar.gz (42 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 42.2/42.2 kB 3.1 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: pillow>=9.4.0 in /usr/local/lib/python3.12/dist-packages (from SAM-2==1.0) (11.3.0)
# Requirement already satisfied: omegaconf<2.4,>=2.2 in /usr/local/lib/python3.12/dist-packages (from hydra-core>=1.3.2->SAM-2==1.0) (2.3.0)
# Requirement already satisfied: antlr4-python3-runtime==4.9.* in /usr/local/lib/python3.12/dist-packages (from hydra-core>=1.3.2->SAM-2==1.0) (4.9.3)
# Requirement already satisfied: packaging in /usr/local/lib/python3.12/dist-packages (from hydra-core>=1.3.2->SAM-2==1.0) (26.0)
# Requirement already satisfied: typing_extensions in /usr/local/lib/python3.12/dist-packages (from iopath>=0.1.10->SAM-2==1.0) (4.15.0)
# Collecting portalocker (from iopath>=0.1.10->SAM-2==1.0)
#   Downloading portalocker-3.2.0-py3-none-any.whl.metadata (8.7 kB)
# Requirement already satisfied: filelock in /usr/local/lib/python3.12/dist-packages (from torch>=2.3.1->SAM-2==1.0) (3.25.2)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.12/dist-packages (from torch>=2.3.1->SAM-2==1.0) (75.2.0)
# Requirement already satisfied: sympy>=1.13.3 in /usr/local/lib/python3.12/dist-packages (from torch>=2.3.1->SAM-2==1.0) (1.14.0)
# Requirement already satisfied: networkx>=2.5.1 in /usr/local/lib/python3.12/dist-packages (from torch>=2.3.1->SAM-2==1.0) (3.6.1)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.12/dist-packages (from torch>=2.3.1->SAM-2==1.0) (3.1.6)
# Requirement already satisfied: fsspec>=0.8.5 in /usr/local/lib/python3.12/dist-packages (from torch>=2.3.1->SAM-2==1.0) (2025.3.0)
# Requirement already satisfied: cuda-bindings==12.9.4 in /usr/local/lib/python3.12/dist-packages (from torch>=2.3.1->SAM-2==1.0) (12.9.4)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.8.93 in /usr/local/lib/python3.12/dist-packages (from torch>=2.3.1->SAM-2==1.0) (12.8.93)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.8.90 in /usr/local/lib/python3.12/dist-packages (from torch>=2.3.1->SAM-2==1.0) (12.8.90)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.8.90 in /usr/local/lib/python3.12/dist-packages (from torch>=2.3.1->SAM-2==1.0) (12.8.90)
# Requirement already satisfied: nvidia-cudnn-cu12==9.10.2.21 in /usr/local/lib/python3.12/dist-packages (from torch>=2.3.1->SAM-2==1.0) (9.10.2.21)
# Requirement already satisfied: nvidia-cublas-cu12==12.8.4.1 in /usr/local/lib/python3.12/dist-packages (from torch>=2.3.1->SAM-2==1.0) (12.8.4.1)
# Requirement already satisfied: nvidia-cufft-cu12==11.3.3.83 in /usr/local/lib/python3.12/dist-packages (from torch>=2.3.1->SAM-2==1.0) (11.3.3.83)
# Requirement already satisfied: nvidia-curand-cu12==10.3.9.90 in /usr/local/lib/python3.12/dist-packages (from torch>=2.3.1->SAM-2==1.0) (10.3.9.90)
# Requirement already satisfied: nvidia-cusolver-cu12==11.7.3.90 in /usr/local/lib/python3.12/dist-packages (from torch>=2.3.1->SAM-2==1.0) (11.7.3.90)
# Requirement already satisfied: nvidia-cusparse-cu12==12.5.8.93 in /usr/local/lib/python3.12/dist-packages (from torch>=2.3.1->SAM-2==1.0) (12.5.8.93)
# Requirement already satisfied: nvidia-cusparselt-cu12==0.7.1 in /usr/local/lib/python3.12/dist-packages (from torch>=2.3.1->SAM-2==1.0) (0.7.1)
# Requirement already satisfied: nvidia-nccl-cu12==2.27.5 in /usr/local/lib/python3.12/dist-packages (from torch>=2.3.1->SAM-2==1.0) (2.27.5)
# Requirement already satisfied: nvidia-nvshmem-cu12==3.4.5 in /usr/local/lib/python3.12/dist-packages (from torch>=2.3.1->SAM-2==1.0) (3.4.5)
# Requirement already satisfied: nvidia-nvtx-cu12==12.8.90 in /usr/local/lib/python3.12/dist-packages (from torch>=2.3.1->SAM-2==1.0) (12.8.90)
# Requirement already satisfied: nvidia-nvjitlink-cu12==12.8.93 in /usr/local/lib/python3.12/dist-packages (from torch>=2.3.1->SAM-2==1.0) (12.8.93)
# Requirement already satisfied: nvidia-cufile-cu12==1.13.1.3 in /usr/local/lib/python3.12/dist-packages (from torch>=2.3.1->SAM-2==1.0) (1.13.1.3)
# Requirement already satisfied: triton==3.6.0 in /usr/local/lib/python3.12/dist-packages (from torch>=2.3.1->SAM-2==1.0) (3.6.0)
# Requirement already satisfied: cuda-pathfinder~=1.1 in /usr/local/lib/python3.12/dist-packages (from cuda-bindings==12.9.4->torch>=2.3.1->SAM-2==1.0) (1.5.0)
# Requirement already satisfied: PyYAML>=5.1.0 in /usr/local/lib/python3.12/dist-packages (from omegaconf<2.4,>=2.2->hydra-core>=1.3.2->SAM-2==1.0) (6.0.3)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.12/dist-packages (from sympy>=1.13.3->torch>=2.3.1->SAM-2==1.0) (1.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.12/dist-packages (from jinja2->torch>=2.3.1->SAM-2==1.0) (3.0.3)
# Downloading hydra_core-1.3.2-py3-none-any.whl (154 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 154.5/154.5 kB 10.0 MB/s eta 0:00:00
# Downloading portalocker-3.2.0-py3-none-any.whl (22 kB)
# Building wheels for collected packages: SAM-2, iopath
#   Building editable for SAM-2 (pyproject.toml) ... done
#   Created wheel for SAM-2: filename=sam_2-1.0-0.editable-cp312-cp312-linux_x86_64.whl size=24134 sha256=cb278a7709c674ff82a523f190794966099b31b7621cfe0bf63dbae4ed1b2d2e
#   Stored in directory: /tmp/pip-ephem-wheel-cache-p7rsxhqq/wheels/2f/6a/01/1151ac797fd33b5746405ed3fb3e55062c7f5abaa4f0a021a4
#   Building wheel for iopath (setup.py) ... done
#   Created wheel for iopath: filename=iopath-0.1.10-py3-none-any.whl size=31527 sha256=1bcc3fe04a5477afef36bfcf548ab0c3fbbe3eed2b7aadf77ac928e8889f4e21
#   Stored in directory: /root/.cache/pip/wheels/7c/96/04/4f5f31ff812f684f69f40cb1634357812220aac58d4698048c
# Successfully built SAM-2 iopath
# Installing collected packages: portalocker, iopath, hydra-core, SAM-2
# Successfully installed SAM-2-1.0 hydra-core-1.3.2 iopath-0.1.10 portalocker-3.2.0

# %%
# install grounding dino
# !cd warehouse-activity-tracker/ && pip install --no-build-isolation -e grounding_dino
# Out:
# Obtaining file:///content/warehouse-activity-tracker/grounding_dino
#   Preparing metadata (setup.py) ... done
# Installing collected packages: groundingdino
#   Running setup.py develop for groundingdino
# Successfully installed groundingdino-0.1.0

# %%
# install extra deps that are not listed in the setup.py
# !pip install supervision addict yapf
# Out:
# Collecting supervision
#   Downloading supervision-0.27.0.post2-py3-none-any.whl.metadata (13 kB)
# Collecting addict
#   Downloading addict-2.4.0-py3-none-any.whl.metadata (1.0 kB)
# Collecting yapf
#   Downloading yapf-0.43.0-py3-none-any.whl.metadata (46 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 46.8/46.8 kB 3.9 MB/s eta 0:00:00
# Requirement already satisfied: numpy>=1.21.2 in /usr/local/lib/python3.12/dist-packages (from supervision) (2.0.2)
# Requirement already satisfied: scipy>=1.10.0 in /usr/local/lib/python3.12/dist-packages (from supervision) (1.16.3)
# Requirement already satisfied: matplotlib>=3.6.0 in /usr/local/lib/python3.12/dist-packages (from supervision) (3.10.0)
# Requirement already satisfied: pyyaml>=5.3 in /usr/local/lib/python3.12/dist-packages (from supervision) (6.0.3)
# Requirement already satisfied: defusedxml>=0.7.1 in /usr/local/lib/python3.12/dist-packages (from supervision) (0.7.1)
# Requirement already satisfied: pillow>=9.4 in /usr/local/lib/python3.12/dist-packages (from supervision) (11.3.0)
# Requirement already satisfied: requests>=2.26.0 in /usr/local/lib/python3.12/dist-packages (from supervision) (2.32.4)
# Requirement already satisfied: tqdm>=4.62.3 in /usr/local/lib/python3.12/dist-packages (from supervision) (4.67.3)
# Requirement already satisfied: opencv-python>=4.5.5.64 in /usr/local/lib/python3.12/dist-packages (from supervision) (4.13.0.92)
# Collecting pyDeprecate<0.6.0,>=0.4.0 (from supervision)
#   Downloading pydeprecate-0.5.0-py3-none-any.whl.metadata (41 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 41.9/41.9 kB 4.5 MB/s eta 0:00:00
# Requirement already satisfied: platformdirs>=3.5.1 in /usr/local/lib/python3.12/dist-packages (from yapf) (4.9.4)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.6.0->supervision) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.6.0->supervision) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.6.0->supervision) (4.62.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.6.0->supervision) (1.5.0)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.6.0->supervision) (26.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.6.0->supervision) (3.3.2)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.6.0->supervision) (2.9.0.post0)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests>=2.26.0->supervision) (3.4.6)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.12/dist-packages (from requests>=2.26.0->supervision) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.12/dist-packages (from requests>=2.26.0->supervision) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.12/dist-packages (from requests>=2.26.0->supervision) (2026.2.25)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.12/dist-packages (from python-dateutil>=2.7->matplotlib>=3.6.0->supervision) (1.17.0)
# Downloading supervision-0.27.0.post2-py3-none-any.whl (217 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 217.4/217.4 kB 14.2 MB/s eta 0:00:00
# Downloading addict-2.4.0-py3-none-any.whl (3.8 kB)
# Downloading yapf-0.43.0-py3-none-any.whl (256 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 256.2/256.2 kB 26.9 MB/s eta 0:00:00
# Downloading pydeprecate-0.5.0-py3-none-any.whl (38 kB)
# Installing collected packages: addict, yapf, pyDeprecate, supervision
# Successfully installed addict-2.4.0 pyDeprecate-0.5.0 supervision-0.27.0.post2 yapf-0.43.0

# %% [markdown]
# # Download Checkpoints

# %%
# For SAM2 checkpoints -- currently using custom to directly get base ckpt
# %cd /content/warehouse-activity-tracker/checkpoints
# !bash download_ckpts_base.sh
# Out:
# /content/warehouse-activity-tracker/checkpoints
# Downloading sam2.1_hiera_base_plus.pt checkpoint...
# --2026-04-06 13:15:31--  https://dl.fbaipublicfiles.com/segment_anything_2/092824/sam2.1_hiera_base_plus.pt
# Resolving dl.fbaipublicfiles.com (dl.fbaipublicfiles.com)... 3.165.160.70, 3.165.160.120, 3.165.160.106, ...
# Connecting to dl.fbaipublicfiles.com (dl.fbaipublicfiles.com)|3.165.160.70|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 323606802 (309M) [application/vnd.snesdev-page-table]
# Saving to: ‘sam2.1_hiera_base_plus.pt’
#
# sam2.1_hiera_base_p 100%[===================>] 308.62M  45.2MB/s    in 7.1s
#
# 2026-04-06 13:15:39 (43.7 MB/s) - ‘sam2.1_hiera_base_plus.pt’ saved [323606802/323606802]
#
# All checkpoints are downloaded successfully.

# %%
# For GDINO checkpoints -- also custom ckpt
# %cd /content/warehouse-activity-tracker/gdino_checkpoints
# !bash download_ckpts_swint.sh
# Out:
# /content/warehouse-activity-tracker/gdino_checkpoints
# Downloading groundingdino_swint_ogc.pth checkpoint...
# --2026-04-06 13:15:39--  https://github.com/IDEA-Research/GroundingDINO/releases/download/v0.1.0-alpha/groundingdino_swint_ogc.pth
# Resolving github.com (github.com)... 140.82.116.4
# Connecting to github.com (github.com)|140.82.116.4|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: https://release-assets.githubusercontent.com/github-production-release-asset/611591640/f221e500-c2fc-4fd3-b84e-8ad92a6923f3?sp=r&sv=2018-11-09&sr=b&spr=https&se=2026-04-06T14%3A08%3A43Z&rscd=attachment%3B+filename%3Dgroundingdino_swint_ogc.pth&rsct=application%2Foctet-stream&skoid=96c2d410-5711-43a1-aedd-ab1947aa7ab0&sktid=398a6654-997b-47e9-b12b-9515b896b4de&skt=2026-04-06T13%3A07%3A50Z&ske=2026-04-06T14%3A08%3A43Z&sks=b&skv=2018-11-09&sig=82QeK8prKhTLDUwPP9tioJRTGhaR5goNf6d59vGIQsI%3D&jwt=eyJ0eXAiOiJKV1QiLCJhbGciOiJIUzI1NiJ9.eyJpc3MiOiJnaXRodWIuY29tIiwiYXVkIjoicmVsZWFzZS1hc3NldHMuZ2l0aHVidXNlcmNvbnRlbnQuY29tIiwia2V5Ijoia2V5MSIsImV4cCI6MTc3NTQ4NDkzOSwibmJmIjoxNzc1NDgxMzM5LCJwYXRoIjoicmVsZWFzZWFzc2V0cHJvZHVjdGlvbi5ibG9iLmNvcmUud2luZG93cy5uZXQifQ.rnT_s4udSIVNXQapebBpIpgFhk_Nd03H_DhP9xvWdQs&response-content-disposition=attachment%3B%20filename%3Dgroundingdino_swint_ogc.pth&response-content-type=application%2Foctet-stream [following]
# --2026-04-06 13:15:39--  https://release-assets.githubusercontent.com/github-production-release-asset/611591640/f221e500-c2fc-4fd3-b84e-8ad92a6923f3?sp=r&sv=2018-11-09&sr=b&spr=https&se=2026-04-06T14%3A08%3A43Z&rscd=attachment%3B+filename%3Dgroundingdino_swint_ogc.pth&rsct=application%2Foctet-stream&skoid=96c2d410-5711-43a1-aedd-ab1947aa7ab0&sktid=398a6654-997b-47e9-b12b-9515b896b4de&skt=2026-04-06T13%3A07%3A50Z&ske=2026-04-06T14%3A08%3A43Z&sks=b&skv=2018-11-09&sig=82QeK8prKhTLDUwPP9tioJRTGhaR5goNf6d59vGIQsI%3D&jwt=eyJ0eXAiOiJKV1QiLCJhbGciOiJIUzI1NiJ9.eyJpc3MiOiJnaXRodWIuY29tIiwiYXVkIjoicmVsZWFzZS1hc3NldHMuZ2l0aHVidXNlcmNvbnRlbnQuY29tIiwia2V5Ijoia2V5MSIsImV4cCI6MTc3NTQ4NDkzOSwibmJmIjoxNzc1NDgxMzM5LCJwYXRoIjoicmVsZWFzZWFzc2V0cHJvZHVjdGlvbi5ibG9iLmNvcmUud2luZG93cy5uZXQifQ.rnT_s4udSIVNXQapebBpIpgFhk_Nd03H_DhP9xvWdQs&response-content-disposition=attachment%3B%20filename%3Dgroundingdino_swint_ogc.pth&response-content-type=application%2Foctet-stream
# Resolving release-assets.githubusercontent.com (release-assets.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to release-assets.githubusercontent.com (release-assets.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 693997677 (662M) [application/octet-stream]
# Saving to: ‘groundingdino_swint_ogc.pth’
#
# groundingdino_swint 100%[===================>] 661.85M   111MB/s    in 6.2s
#
# 2026-04-06 13:15:45 (107 MB/s) - ‘groundingdino_swint_ogc.pth’ saved [693997677/693997677]
#
# All checkpoints are downloaded successfully.

# %% [markdown]
# # Testing of GDINO 1.0 Backbone on HuggingFace Model and Single Image
#
# Will be runing the demo file, which contains video preprocessing like separating into several frames.

# %%
# returning back to project root
# %cd /content/warehouse-activity-tracker/
# Out:
# /content/warehouse-activity-tracker

# %% [markdown]
# # Testing of GDINO 1.0 Backbone on HuggingFace Model and A Video
#
# For this, I need to use this script directly: `grounded_sam2_tracking_demo_custom_video_input_gd1.0_hf_model.py`.
#
# Note that I have modified it locally, so make sure to adjust the path when needed.
#
# Don't forget to edit the model if necessary.
#
# Remember the start frame formulation when stride is applied (current stride set to 3):
#
# ```
# original_frame_idx = start + extracted_idx * stride
# original_frame_idx = 0 + <what initial frame> * 3
# ```

# %%
# !python grounded_sam2_hf_judge.py \
    --video-path /content/drive/MyDrive/warehouse_videos/unsafe_sandal.mp4 \
    --output-video-path ./unsafe_sandal_tracking_demo.mp4 \
    --text-prompt "person. sandal. pallet jack. pallet. stack. shorts." \
    --frame-start 120 \
    --frame-stride 8
# Out:
# UserWarning: Flash Attention is disabled as it requires a GPU with Ampere (8.0) CUDA capability.
# Warning: You are sending unauthenticated requests to the HF Hub. Please set a HF_TOKEN to enable higher rate limits and faster downloads.
# WARNING:huggingface_hub.utils._http:Warning: You are sending unauthenticated requests to the HF Hub. Please set a HF_TOKEN to enable higher rate limits and faster downloads.
# The image processor of type `GroundingDinoImageProcessor` is now loaded as a fast processor by default, even if the model checkpoint was saved with a slow processor. This is a breaking change and may produce slightly different outputs. To continue using the slow processor, instantiate this class with `use_fast=False`.
#
ageProcessor` is now loaded as a fast processor by default, even if the model checkpoint was saved with a slow processor. This is a breaking change and may produce slightly different outputs. To continue using the slow processor, instantiate this class with `use_fast=False`.
# Loading weights: 100% 990/990 [00:01<00:00, 650.81it/s, Materializing param=model.text_projection.weight]
# VideoInfo(width=1280, height=720, fps=50, total_frames=297)
# Saving Video Frames with Higher Stride and Lower Res: 79it [00:01, 68.74it/s]
# frame loading (JPEG): 100% 79/79 [00:02<00:00, 35.78it/s]
# [[177.82439    1.336416 544.874    359.21014 ]
#  [546.63513  142.23743  639.593    265.27316 ]
#  [447.3296    77.46202  567.1893   171.59341 ]
#  [607.77734   50.334602 639.8672   146.0622  ]
#  [547.1264   248.43488  582.9358   264.69406 ]]
# ['forklift', 'person', 'person', 'person', 'shoes']
# UserWarning: cannot import name '_C' from 'sam2' (/content/warehouse-activity-tracker/sam2/__init__.py)
#
# Skipping the post-processing step due to the error above. You can still use SAM 2 and it's OK to ignore the error above, although some post-processing functionality may be limited (which doesn't affect the results in most cases; see https://github.com/facebookresearch/sam2/blob/main/INSTALL.md).
# propagate in video: 100% 79/79 [02:44<00:00,  2.08s/it]
# [Frame 0] Critical (0.85) - Worker is too close to equipment 'forklift' (distance=8.0px).
# [Frame 1] Critical (0.85) - Worker is too close to equipment 'forklift' (distance=8.0px).
# [Frame 2] Critical (0.85) - Worker is too close to equipment 'forklift' (distance=8.0px).
# [Frame 3] Critical (0.85) - Worker is too close to equipment 'forklift' (distance=7.0px).
# [Frame 4] Critical (0.85) - Worker is too close to equipment 'forklift' (distance=2.0px).
# [Frame 5] Critical (0.85) - Worker is too close to equipment 'forklift' (distance=3.0px).
# [Frame 6] Critical (0.85) - Worker is too close to equipment 'forklift' (distance=1.0px).
# [Frame 7] Critical (0.85) - Worker is too close to equipment 'forklift' (distance=2.0px).
# [Frame 8] Critical (0.85) - Worker is too close to equipment 'forklift' (distance=3.0px).
# [Frame 9] Critical (0.85) - Worker is too close to equipment 'forklift' (distance=6.0px).
# [Frame 10] Critical (0.85) - Worker is too close to equipment 'forklift' (distance=6.0px).
# [Frame 11] Critical (0.85) - Worker is too close to equipment 'forklift' (distance=2.0px).
# [Frame 12] Critical (0.85) - Worker is too close to equipment 'forklift' (distance=1.0px).
# [Frame 13] Critical (0.85) - Worker is too close to equipment 'forklift' (distance=2.0px).
# [Frame 14] Critical (0.85) - Worker is too close to equipment 'forklift' (distance=1.0px).
# [Frame 15] Critical (0.85) - Worker is too close to equipment 'forklift' (distance=7.0px).
# [Frame 16] Critical (0.85) - Worker is too close to equipment 'forklift' (distance=10.0px).
# [Frame 17] Critical (0.85) - Worker is too close to equipment 'forklift' (distance=11.0px).
# [Frame 18] Critical (0.85) - Worker is too close to equipment 'forklift' (distance=11.0px).
# [Frame 19] Critical (0.85) - Worker is too close to equipment 'forklift' (distance=12.0px).
# [Frame 20] Critical (0.85) - Worker is too close to equipment 'forklift' (distance=11.0px).
# [Frame 21] Critical (0.85) - Worker is too close to equipment 'forklift' (distance=11.0px).
# [Frame 22] Critical (0.85) - Worker is too close to equipment 'forklift' (distance=11.0px).
# [Frame 23] Critical (0.85) - Worker is too close to equipment 'forklift' (distance=12.0px).
# [Frame 24] Critical (0.85) - Worker is too close to equipment 'forklift' (distance=12.0px).
# [Frame 25] Critical (0.85) - Worker is too close to equipment 'forklift' (distance=12.0px).
# [Frame 26] Critical (0.85) - Worker is too close to equipment 'forklift' (distance=13.0px).
# [Frame 27] Critical (0.85) - Worker is too close to equipment 'forklift' (distance=13.0px).
# [Frame 28] Critical (0.85) - Worker is too close to equipment 'forklift' (distance=13.0px).
# [Frame 29] Critical (0.85) - Worker is too close to equipment 'forklift' (distance=14.0px).
# [Frame 30] Critical (0.85) - Worker is too close to equipment 'forklift' (distance=14.0px).
# [Frame 31] Critical (0.85) - Worker is too close to equipment 'forklift' (distance=0.0px).
# [Frame 32] Critical (0.85) - Worker is too close to equipment 'forklift' (distance=0.0px).
# [Frame 33] Critical (0.85) - Worker is too close to equipment 'forklift' (distance=0.0px).
# [Frame 34] Critical (0.85) - Worker is too close to equipment 'forklift' (distance=0.0px).
# [Frame 35] Critical (0.85) - Worker is too close to equipment 'forklift' (distance=0.0px).
# [Frame 36] Critical (0.85) - Worker is too close to equipment 'forklift' (distance=0.0px).
# [Frame 37] Critical (0.85) - Worker is too close to equipment 'forklift' (distance=0.0px).
# [Frame 38] Critical (0.85) - Worker is too close to equipment 'forklift' (distance=0.0px).
# [Frame 39] Critical (0.85) - Worker is too close to equipment 'forklift' (distance=0.0px).
# [Frame 40] Critical (0.85) - Worker is too close to equipment 'forklift' (distance=0.0px).
# [Frame 41] Critical (0.85) - Worker is too close to equipment 'forklift' (distance=0.0px).
# [Frame 42] Critical (0.85) - Worker is too close to equipment 'forklift' (distance=0.0px).
# [Frame 43] Critical (0.85) - Worker is too close to equipment 'forklift' (distance=0.0px).
# [Frame 44] Critical (0.85) - Worker is too close to equipment 'forklift' (distance=0.0px).
# [Frame 45] Critical (0.85) - Worker is too close to equipment 'forklift' (distance=0.0px).
# [Frame 46] Critical (0.85) - Worker is too close to equipment 'forklift' (distance=0.0px).
# [Frame 47] Critical (0.85) - Worker is too close to equipment 'forklift' (distance=0.0px).
# [Frame 48] Critical (0.85) - Worker is too close to equipment 'forklift' (distance=0.0px).
# [Frame 49] Critical (0.85) - Worker is too close to equipment 'forklift' (distance=0.0px).
# [Frame 50] Critical (0.85) - Worker is too close to equipment 'forklift' (distance=0.0px).
# [Frame 51] Critical (0.85) - Worker is too close to equipment 'forklift' (distance=0.0px).
# [Frame 52] Critical (0.85) - Worker is too close to equipment 'forklift' (distance=0.0px).
# [Frame 53] Critical (0.85) - Worker is too close to equipment 'forklift' (distance=0.0px).
# [Frame 54] Critical (0.85) - Worker is too close to equipment 'forklift' (distance=0.0px).
# [Frame 55] Critical (0.85) - Worker is too close to equipment 'forklift' (distance=0.0px).
# [Frame 56] Critical (0.85) - Worker is too close to equipment 'forklift' (distance=0.0px).
# [Frame 57] Critical (0.85) - Worker is too close to equipment 'forklift' (distance=0.0px).
# [Frame 58] Critical (0.85) - Worker is too close to equipment 'forklift' (distance=0.0px).
# [Frame 59] Critical (0.85) - Worker is too close to equipment 'forklift' (distance=0.0px).
# [Frame 60] Critical (0.85) - Worker is too close to equipment 'forklift' (distance=0.0px).
# [Frame 61] Critical (0.85) - Worker is too close to equipment 'forklift' (distance=0.0px).
# [Frame 62] Critical (0.85) - Worker is too close to equipment 'forklift' (distance=0.0px).
# [Frame 63] Critical (0.85) - Worker is too close to equipment 'forklift' (distance=0.0px).
# [Frame 64] Critical (0.85) - Worker is too close to equipment 'forklift' (distance=0.0px).
# [Frame 65] Critical (0.85) - Worker is too close to equipment 'forklift' (distance=0.0px).
# [Frame 66] Critical (0.85) - Worker is too close to equipment 'forklift' (distance=0.0px).
# [Frame 67] Critical (0.85) - Worker is too close to equipment 'forklift' (distance=0.0px).
# [Frame 68] Critical (0.85) - Worker is too close to equipment 'forklift' (distance=0.0px).
# [Frame 69] Critical (0.85) - Worker is too close to equipment 'forklift' (distance=0.0px).
# [Frame 70] Critical (0.85) - Worker is too close to equipment 'forklift' (distance=0.0px).
# [Frame 71] Critical (0.85) - Worker is too close to equipment 'forklift' (distance=0.0px).
# [Frame 72] Critical (0.85) - Worker is too close to equipment 'forklift' (distance=0.0px).
# [Frame 73] Critical (0.85) - Worker is too close to equipment 'forklift' (distance=0.0px).
# [Frame 74] Critical (0.85) - Worker is too close to equipment 'forklift' (distance=0.0px).
# [Frame 75] Critical (0.85) - Worker is too close to equipment 'forklift' (distance=0.0px).
# [Frame 76] Critical (0.85) - Worker is too close to equipment 'forklift' (distance=0.0px).
# [Frame 77] Critical (0.85) - Worker is too close to equipment 'forklift' (distance=0.0px).
# [Frame 78] Critical (0.85) - Worker is too close to equipment 'forklift' (distance=0.0px).
# ['annotated_frame_00000.jpg', 'annotated_frame_00001.jpg', 'annotated_frame_00002.jpg', 'annotated_frame_00003.jpg', 'annotated_frame_00004.jpg', 'annotated_frame_00005.jpg', 'annotated_frame_00006.jpg', 'annotated_frame_00007.jpg', 'annotated_frame_00008.jpg', 'annotated_frame_00009.jpg', 'annotated_frame_00010.jpg', 'annotated_frame_00011.jpg', 'annotated_frame_00012.jpg', 'annotated_frame_00013.jpg', 'annotated_frame_00014.jpg', 'annotated_frame_00015.jpg', 'annotated_frame_00016.jpg', 'annotated_frame_00017.jpg', 'annotated_frame_00018.jpg', 'annotated_frame_00019.jpg', 'annotated_frame_00020.jpg', 'annotated_frame_00021.jpg', 'annotated_frame_00022.jpg', 'annotated_frame_00023.jpg', 'annotated_frame_00024.jpg', 'annotated_frame_00025.jpg', 'annotated_frame_00026.jpg', 'annotated_frame_00027.jpg', 'annotated_frame_00028.jpg', 'annotated_frame_00029.jpg', 'annotated_frame_00030.jpg', 'annotated_frame_00031.jpg', 'annotated_frame_00032.jpg', 'annotated_frame_00033.jpg', 'annotated_frame_00034.jpg', 'annotated_frame_00035.jpg', 'annotated_frame_00036.jpg', 'annotated_frame_00037.jpg', 'annotated_frame_00038.jpg', 'annotated_frame_00039